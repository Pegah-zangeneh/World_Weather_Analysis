# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import time as time

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 750

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0bc6eff329d24cfa619d67172be6dea1&q=Boston

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_description,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | kapaa
# Processing Record 3 of Set 1 | honiara
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | mount gambier
# Processing Record 6 of Set 1 | jamestown
# Processing Record 7 of Set 1 | kaitangata
# Processing Record 8 of Set 1 | san andres
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | upernavik
# Processing Record 11 of Set 1 | moissala
# Processing Record 12 of Set 1 | karkaralinsk
# City not found. Skipping...
# Processing Record 13 of Set 1 | hermanus
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | avarua
# Processing Record 16 of Set 1 | basco
# Processing Record 17 of Set 1 | yinchuan
# Processing Record 18 of Set 1 | grindavik
# Processing Record 19 of Set 1 | anzio
# Processing Record 20 of Set 1 | victoria
# Processing Record 21 of Set 1 | anuradhapura
# Processing Record 22 of Set 1 | maarianhamina
# Processing Record 23 of Set 1 | airai
# Processing Record 24 of Set 1 | mizan teferi
# Processing Record 25 of Set 1 | tual
# Processing Record 26 of Set 1 | dalhousie
# Processing Record 27 of Set 1 | saint george
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | atuona
# Processing Record 30 of Set 1 | las vegas
# Processing Record 31 of Set 1 | shache
# Processing Record 32 of Set 1 | thompson
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | vardo
# Processing Record 35 of Set 1 | rio gallegos
# Processing Record 36 of Set 1 | poindimie
# Processing Record 37 of Set 1 | tezpur
# Processing Record 38 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 1 | khatanga
# Processing Record 41 of Set 1 | vanimo
# Processing Record 42 of Set 1 | maniwaki
# Processing Record 43 of Set 1 | rawson
# Processing Record 44 of Set 1 | college
# Processing Record 45 of Set 1 | ridgecrest
# Processing Record 46 of Set 1 | ceica
# Processing Record 47 of Set 1 | albany
# Processing Record 48 of Set 1 | mahebourg
# Processing Record 49 of Set 1 | hilo
# Processing Record 50 of Set 1 | te anau
# Processing Record 1 of Set 2 | dakar
# Processing Record 2 of Set 2 | tuktoyaktuk
# Processing Record 3 of Set 2 | guerrero negro
# Processing Record 4 of Set 2 | lazaro cardenas
# Processing Record 5 of Set 2 | ponta do sol
# Processing Record 6 of Set 2 | susurluk
# Processing Record 7 of Set 2 | ukiah
# Processing Record 8 of Set 2 | barrow
# Processing Record 9 of Set 2 | brest
# Processing Record 10 of Set 2 | mar del plata
# Processing Record 11 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 2 | ariquemes
# Processing Record 13 of Set 2 | saldanha
# Processing Record 14 of Set 2 | tasiilaq
# Processing Record 15 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 2 | vaini
# Processing Record 18 of Set 2 | narsaq
# Processing Record 19 of Set 2 | srednekolymsk
# Processing Record 20 of Set 2 | teguise
# Processing Record 21 of Set 2 | bethel
# Processing Record 22 of Set 2 | abapo
# Processing Record 23 of Set 2 | butaritari
# Processing Record 24 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 2 | port lincoln
# Processing Record 26 of Set 2 | bredasdorp
# Processing Record 27 of Set 2 | torbay
# Processing Record 28 of Set 2 | dillon
# Processing Record 29 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 2 | avera
# Processing Record 31 of Set 2 | batie
# Processing Record 32 of Set 2 | thinadhoo
# Processing Record 33 of Set 2 | sonoita
# Processing Record 34 of Set 2 | haaren
# Processing Record 35 of Set 2 | nanakuli
# Processing Record 36 of Set 2 | sitka
# Processing Record 37 of Set 2 | constitucion
# Processing Record 38 of Set 2 | buraydah
# Processing Record 39 of Set 2 | berezovyy
# Processing Record 40 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 2 | oranjemund
# Processing Record 42 of Set 2 | nouadhibou
# Processing Record 43 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 2 | kalga
# Processing Record 45 of Set 2 | provideniya
# Processing Record 46 of Set 2 | tabou
# Processing Record 47 of Set 2 | cape town
# Processing Record 48 of Set 2 | cherskiy
# Processing Record 49 of Set 2 | lebu
# Processing Record 50 of Set 2 | dingle
# Processing Record 1 of Set 3 | severo-kurilsk
# Processing Record 2 of Set 3 | codrington
# Processing Record 3 of Set 3 | dikson
# Processing Record 4 of Set 3 | naliya
# Processing Record 5 of Set 3 | carutapera
# Processing Record 6 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 3 | lompoc
# Processing Record 8 of Set 3 | punta arenas
# Processing Record 9 of Set 3 | clyde river
# Processing Record 10 of Set 3 | longyearbyen
# Processing Record 11 of Set 3 | ostrovnoy
# Processing Record 12 of Set 3 | panzhihua
# Processing Record 13 of Set 3 | west bay
# Processing Record 14 of Set 3 | saskylakh
# Processing Record 15 of Set 3 | sarankhola
# Processing Record 16 of Set 3 | cukai
# Processing Record 17 of Set 3 | mitu
# Processing Record 18 of Set 3 | fairbanks
# Processing Record 19 of Set 3 | chuy
# Processing Record 20 of Set 3 | dutse
# Processing Record 21 of Set 3 | bolu
# Processing Record 22 of Set 3 | lorengau
# Processing Record 23 of Set 3 | bikin
# Processing Record 24 of Set 3 | lavrentiya
# Processing Record 25 of Set 3 | kuching
# Processing Record 26 of Set 3 | victoria point
# Processing Record 27 of Set 3 | port keats
# Processing Record 28 of Set 3 | bathsheba
# Processing Record 29 of Set 3 | qaanaaq
# Processing Record 30 of Set 3 | puerto ayacucho
# Processing Record 31 of Set 3 | chokurdakh
# Processing Record 32 of Set 3 | soe
# Processing Record 33 of Set 3 | odienne
# Processing Record 34 of Set 3 | cap malheureux
# Processing Record 35 of Set 3 | ambilobe
# Processing Record 36 of Set 3 | general roca
# Processing Record 37 of Set 3 | nieuw amsterdam
# Processing Record 38 of Set 3 | sompeta
# Processing Record 39 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 3 | lensk
# Processing Record 41 of Set 3 | castro
# Processing Record 42 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 3 | wenzhou
# Processing Record 44 of Set 3 | chincholi
# Processing Record 45 of Set 3 | luderitz
# Processing Record 46 of Set 3 | karabash
# Processing Record 47 of Set 3 | andilamena
# Processing Record 48 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 3 | bandrele
# Processing Record 50 of Set 3 | piacabucu
# Processing Record 1 of Set 4 | halifax
# Processing Record 2 of Set 4 | cockburn harbour
# City not found. Skipping...
# Processing Record 3 of Set 4 | luanda
# Processing Record 4 of Set 4 | tilichiki
# Processing Record 5 of Set 4 | tapaua
# City not found. Skipping...
# Processing Record 6 of Set 4 | reyes
# Processing Record 7 of Set 4 | laguna
# Processing Record 8 of Set 4 | samarai
# Processing Record 9 of Set 4 | burns lake
# Processing Record 10 of Set 4 | rodionovo-nesvetayskaya
# Processing Record 11 of Set 4 | bambous virieux
# Processing Record 12 of Set 4 | rocha
# Processing Record 13 of Set 4 | nikolskoye
# Processing Record 14 of Set 4 | port alfred
# Processing Record 15 of Set 4 | nizhniy odes
# Processing Record 16 of Set 4 | erenhot
# Processing Record 17 of Set 4 | pangnirtung
# Processing Record 18 of Set 4 | port elizabeth
# Processing Record 19 of Set 4 | klaksvik
# Processing Record 20 of Set 4 | hoi an
# Processing Record 21 of Set 4 | vernon
# Processing Record 22 of Set 4 | coahuayana
# Processing Record 23 of Set 4 | isangel
# Processing Record 24 of Set 4 | haimen
# Processing Record 25 of Set 4 | alyangula
# Processing Record 26 of Set 4 | ende
# Processing Record 27 of Set 4 | carnarvon
# Processing Record 28 of Set 4 | port hardy
# Processing Record 29 of Set 4 | tiksi
# Processing Record 30 of Set 4 | ilulissat
# Processing Record 31 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 32 of Set 4 | faanui
# Processing Record 33 of Set 4 | pinotepa de don luis
# Processing Record 34 of Set 4 | meulaboh
# Processing Record 35 of Set 4 | homer
# Processing Record 36 of Set 4 | saint-philippe
# Processing Record 37 of Set 4 | yuancheng
# Processing Record 38 of Set 4 | veraval
# Processing Record 39 of Set 4 | jeronimo monteiro
# Processing Record 40 of Set 4 | touros
# Processing Record 41 of Set 4 | vestmanna
# Processing Record 42 of Set 4 | mehamn
# Processing Record 43 of Set 4 | yangzhou
# Processing Record 44 of Set 4 | arraial do cabo
# Processing Record 45 of Set 4 | kyzyl-suu
# Processing Record 46 of Set 4 | cabo san lucas
# Processing Record 47 of Set 4 | bluff
# Processing Record 48 of Set 4 | bichena
# Processing Record 49 of Set 4 | adrar
# Processing Record 50 of Set 4 | zhigansk
# Processing Record 1 of Set 5 | la ronge
# Processing Record 2 of Set 5 | kavieng
# Processing Record 3 of Set 5 | georgetown
# Processing Record 4 of Set 5 | kaeo
# Processing Record 5 of Set 5 | kenai
# Processing Record 6 of Set 5 | necochea
# Processing Record 7 of Set 5 | olafsvik
# Processing Record 8 of Set 5 | riyadh
# Processing Record 9 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 5 | karratha
# Processing Record 11 of Set 5 | iqaluit
# Processing Record 12 of Set 5 | camacha
# Processing Record 13 of Set 5 | jiexiu
# Processing Record 14 of Set 5 | aksu
# Processing Record 15 of Set 5 | mahaicony
# City not found. Skipping...
# Processing Record 16 of Set 5 | puerto ayora
# Processing Record 17 of Set 5 | stoyba
# City not found. Skipping...
# Processing Record 18 of Set 5 | san quintin
# Processing Record 19 of Set 5 | kutum
# Processing Record 20 of Set 5 | tazovskiy
# Processing Record 21 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 22 of Set 5 | port pirie
# Processing Record 23 of Set 5 | broome
# Processing Record 24 of Set 5 | san patricio
# Processing Record 25 of Set 5 | abha
# Processing Record 26 of Set 5 | ribeira grande
# Processing Record 27 of Set 5 | lake charles
# Processing Record 28 of Set 5 | pajapan
# Processing Record 29 of Set 5 | hami
# Processing Record 30 of Set 5 | san cristobal
# Processing Record 31 of Set 5 | uige
# Processing Record 32 of Set 5 | kruisfontein
# Processing Record 33 of Set 5 | murray bridge
# Processing Record 34 of Set 5 | susanville
# Processing Record 35 of Set 5 | ozgon
# City not found. Skipping...
# Processing Record 36 of Set 5 | hithadhoo
# Processing Record 37 of Set 5 | okhotsk
# Processing Record 38 of Set 5 | newport
# Processing Record 39 of Set 5 | morros
# Processing Record 40 of Set 5 | roebourne
# Processing Record 41 of Set 5 | ampanihy
# Processing Record 42 of Set 5 | verkhnevilyuysk
# Processing Record 43 of Set 5 | lasa
# Processing Record 44 of Set 5 | matara
# Processing Record 45 of Set 5 | rong kwang
# Processing Record 46 of Set 5 | alofi
# Processing Record 47 of Set 5 | namatanai
# Processing Record 48 of Set 5 | nanortalik
# Processing Record 49 of Set 5 | gallup
# Processing Record 50 of Set 5 | chibuto
# Processing Record 1 of Set 6 | ercis
# Processing Record 2 of Set 6 | aswan
# Processing Record 3 of Set 6 | bontang
# Processing Record 4 of Set 6 | hamilton
# Processing Record 5 of Set 6 | risor
# Processing Record 6 of Set 6 | pochutla
# Processing Record 7 of Set 6 | agarak
# Processing Record 8 of Set 6 | malkapur
# Processing Record 9 of Set 6 | imperia
# Processing Record 10 of Set 6 | hasaki
# Processing Record 11 of Set 6 | varhaug
# Processing Record 12 of Set 6 | waingapu
# Processing Record 13 of Set 6 | teahupoo
# Processing Record 14 of Set 6 | bilibino
# Processing Record 15 of Set 6 | gizo
# Processing Record 16 of Set 6 | syracuse
# Processing Record 17 of Set 6 | banjarmasin
# Processing Record 18 of Set 6 | fare
# Processing Record 19 of Set 6 | fortuna
# Processing Record 20 of Set 6 | portland
# Processing Record 21 of Set 6 | the valley
# Processing Record 22 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 23 of Set 6 | koupela
# Processing Record 24 of Set 6 | los llanos de aridane
# Processing Record 25 of Set 6 | westport
# Processing Record 26 of Set 6 | waren
# Processing Record 27 of Set 6 | poum
# Processing Record 28 of Set 6 | yarim
# Processing Record 29 of Set 6 | buala
# Processing Record 30 of Set 6 | yulara
# Processing Record 31 of Set 6 | begles
# Processing Record 32 of Set 6 | husavik
# Processing Record 33 of Set 6 | aqtobe
# Processing Record 34 of Set 6 | bakhmach
# Processing Record 35 of Set 6 | do gonbadan
# Processing Record 36 of Set 6 | new norfolk
# Processing Record 37 of Set 6 | east london
# Processing Record 38 of Set 6 | porbandar
# Processing Record 39 of Set 6 | maharajganj
# Processing Record 40 of Set 6 | mujiayingzi
# Processing Record 41 of Set 6 | esperance
# Processing Record 42 of Set 6 | atar
# Processing Record 43 of Set 6 | palm valley
# Processing Record 44 of Set 6 | juegang
# Processing Record 45 of Set 6 | huilong
# Processing Record 46 of Set 6 | soure
# Processing Record 47 of Set 6 | yining
# Processing Record 48 of Set 6 | gobabis
# Processing Record 49 of Set 6 | huarmey
# Processing Record 50 of Set 6 | kidal
# Processing Record 1 of Set 7 | peleduy
# Processing Record 2 of Set 7 | nyurba
# Processing Record 3 of Set 7 | mamallapuram
# Processing Record 4 of Set 7 | dingzhou
# Processing Record 5 of Set 7 | geraldton
# Processing Record 6 of Set 7 | vazante
# Processing Record 7 of Set 7 | vila do maio
# Processing Record 8 of Set 7 | serov
# Processing Record 9 of Set 7 | ketchikan
# Processing Record 10 of Set 7 | marawi
# Processing Record 11 of Set 7 | lebanon
# Processing Record 12 of Set 7 | calmar
# Processing Record 13 of Set 7 | la rinconada
# Processing Record 14 of Set 7 | cidreira
# Processing Record 15 of Set 7 | coari
# Processing Record 16 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 17 of Set 7 | ancud
# Processing Record 18 of Set 7 | baneasa
# Processing Record 19 of Set 7 | sampit
# Processing Record 20 of Set 7 | newala
# Processing Record 21 of Set 7 | anloga
# Processing Record 22 of Set 7 | asyut
# Processing Record 23 of Set 7 | lubango
# Processing Record 24 of Set 7 | chato
# Processing Record 25 of Set 7 | khash
# Processing Record 26 of Set 7 | beian
# Processing Record 27 of Set 7 | anadyr
# Processing Record 28 of Set 7 | coquimbo
# Processing Record 29 of Set 7 | port-gentil
# Processing Record 30 of Set 7 | moth
# Processing Record 31 of Set 7 | banjar
# Processing Record 32 of Set 7 | great falls
# Processing Record 33 of Set 7 | haines junction
# Processing Record 34 of Set 7 | fomboni
# Processing Record 35 of Set 7 | benghazi
# Processing Record 36 of Set 7 | vila velha
# Processing Record 37 of Set 7 | vila franca do campo
# Processing Record 38 of Set 7 | rabo de peixe
# Processing Record 39 of Set 7 | itoman
# Processing Record 40 of Set 7 | ypsonas
# Processing Record 41 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 7 | mulege
# Processing Record 43 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 7 | griffith
# Processing Record 45 of Set 7 | ji-parana
# City not found. Skipping...
# Processing Record 46 of Set 7 | vila
# Processing Record 47 of Set 7 | nome
# Processing Record 48 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 49 of Set 7 | skagastrond
# City not found. Skipping...
# Processing Record 50 of Set 7 | chernyshevskiy
# Processing Record 1 of Set 8 | okmulgee
# Processing Record 2 of Set 8 | antofagasta
# Processing Record 3 of Set 8 | pauini
# Processing Record 4 of Set 8 | churapcha
# Processing Record 5 of Set 8 | lavumisa
# Processing Record 6 of Set 8 | kodinsk
# Processing Record 7 of Set 8 | sao filipe
# Processing Record 8 of Set 8 | grootfontein
# Processing Record 9 of Set 8 | mayumba
# Processing Record 10 of Set 8 | capinota
# Processing Record 11 of Set 8 | hobyo
# Processing Record 12 of Set 8 | teya
# Processing Record 13 of Set 8 | cuiluan
# Processing Record 14 of Set 8 | xining
# Processing Record 15 of Set 8 | tecoanapa
# Processing Record 16 of Set 8 | kita
# Processing Record 17 of Set 8 | mahajanga
# Processing Record 18 of Set 8 | zmeinogorsk
# Processing Record 19 of Set 8 | mayo
# Processing Record 20 of Set 8 | kodiak
# Processing Record 21 of Set 8 | chapais
# Processing Record 22 of Set 8 | ambon
# Processing Record 23 of Set 8 | kurilsk
# Processing Record 24 of Set 8 | taoudenni
# Processing Record 25 of Set 8 | itatskiy
# Processing Record 26 of Set 8 | ngunguru
# Processing Record 27 of Set 8 | shimoda
# Processing Record 28 of Set 8 | talnakh
# Processing Record 29 of Set 8 | new lenox
# Processing Record 30 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 31 of Set 8 | aykhal
# Processing Record 32 of Set 8 | puebla
# Processing Record 33 of Set 8 | kleive
# Processing Record 34 of Set 8 | coihaique
# Processing Record 35 of Set 8 | thai nguyen
# Processing Record 36 of Set 8 | tautira
# Processing Record 37 of Set 8 | price
# Processing Record 38 of Set 8 | borlange
# City not found. Skipping...
# Processing Record 39 of Set 8 | pevek
# Processing Record 40 of Set 8 | goundam
# Processing Record 41 of Set 8 | kahului
# Processing Record 42 of Set 8 | atambua
# Processing Record 43 of Set 8 | tignoan
# Processing Record 44 of Set 8 | sorland
# Processing Record 45 of Set 8 | gat
# Processing Record 46 of Set 8 | saint-pierre
# Processing Record 47 of Set 8 | arrifes
# Processing Record 48 of Set 8 | itarema
# Processing Record 49 of Set 8 | mahibadhoo
# Processing Record 50 of Set 8 | tura
# Processing Record 1 of Set 9 | makakilo city
# Processing Record 2 of Set 9 | marystown
# Processing Record 3 of Set 9 | saint anthony
# Processing Record 4 of Set 9 | bilma
# Processing Record 5 of Set 9 | denpasar
# Processing Record 6 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 7 of Set 9 | hualmay
# Processing Record 8 of Set 9 | dhanera
# Processing Record 9 of Set 9 | muroto
# Processing Record 10 of Set 9 | fort nelson
# Processing Record 11 of Set 9 | juneau
# Processing Record 12 of Set 9 | puerto escondido
# Processing Record 13 of Set 9 | amuntai
# Processing Record 14 of Set 9 | kamaishi
# Processing Record 15 of Set 9 | huaicheng
# Processing Record 16 of Set 9 | patos
# Processing Record 17 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 9 | vestmannaeyjar
# Processing Record 19 of Set 9 | seoul
# Processing Record 20 of Set 9 | churu
# Processing Record 21 of Set 9 | mae sai
# Processing Record 22 of Set 9 | fukue
# Processing Record 23 of Set 9 | mavrovi anovi
# Processing Record 24 of Set 9 | marsh harbour
# Processing Record 25 of Set 9 | manadhoo
# Processing Record 26 of Set 9 | quatre cocos
# Processing Record 27 of Set 9 | kupang
# Processing Record 28 of Set 9 | izumo
# Processing Record 29 of Set 9 | awjilah
# Processing Record 30 of Set 9 | quechultenango
# Processing Record 31 of Set 9 | neuquen
# Processing Record 32 of Set 9 | goderich
# Processing Record 33 of Set 9 | baruun-urt
# Processing Record 34 of Set 9 | vyartsilya
# Processing Record 35 of Set 9 | gaoual
# Processing Record 36 of Set 9 | saint-francois
# Processing Record 37 of Set 9 | allapalli
# Processing Record 38 of Set 9 | katsina
# Processing Record 39 of Set 9 | nerchinskiy zavod
# Processing Record 40 of Set 9 | balimo
# City not found. Skipping...
# Processing Record 41 of Set 9 | san clemente
# Processing Record 42 of Set 9 | mattoon
# Processing Record 43 of Set 9 | port macquarie
# Processing Record 44 of Set 9 | dalaba
# Processing Record 45 of Set 9 | sioux lookout
# Processing Record 46 of Set 9 | la paz
# Processing Record 47 of Set 9 | shakhtinsk
# Processing Record 48 of Set 9 | gimli
# Processing Record 49 of Set 9 | tiarei
# Processing Record 50 of Set 9 | boyolangu
# Processing Record 1 of Set 10 | norman wells
# Processing Record 2 of Set 10 | skjervoy
# Processing Record 3 of Set 10 | buturlino
# Processing Record 4 of Set 10 | charters towers
# Processing Record 5 of Set 10 | tigil
# Processing Record 6 of Set 10 | hambantota
# Processing Record 7 of Set 10 | obsharovka
# Processing Record 8 of Set 10 | springbok
# Processing Record 9 of Set 10 | caravelas
# Processing Record 10 of Set 10 | sergeyevka
# Processing Record 11 of Set 10 | sokoto
# Processing Record 12 of Set 10 | panjab
# Processing Record 13 of Set 10 | sedelnikovo
# City not found. Skipping...
# Processing Record 14 of Set 10 | kavaratti
# Processing Record 15 of Set 10 | bama
# Processing Record 16 of Set 10 | kracheh
# City not found. Skipping...
# Processing Record 17 of Set 10 | aksarka
# Processing Record 18 of Set 10 | zaysan
# Processing Record 19 of Set 10 | lagoa
# Processing Record 20 of Set 10 | paciran
# Processing Record 21 of Set 10 | mount isa
# Processing Record 22 of Set 10 | hyeres
# Processing Record 23 of Set 10 | flin flon
# Processing Record 24 of Set 10 | makat
# Processing Record 25 of Set 10 | multai
# Processing Record 26 of Set 10 | alice springs
# Processing Record 27 of Set 10 | prince rupert
# Processing Record 28 of Set 10 | north bend
# Processing Record 29 of Set 10 | wattegama
# Processing Record 30 of Set 10 | tuatapere
# Processing Record 31 of Set 10 | rio grande
# Processing Record 32 of Set 10 | qaqortoq
# Processing Record 33 of Set 10 | najran
# Processing Record 34 of Set 10 | jabinyanah
# Processing Record 35 of Set 10 | suchdol nad luznici
# Processing Record 36 of Set 10 | luau
# Processing Record 37 of Set 10 | celendin
# Processing Record 38 of Set 10 | beringovskiy
# Processing Record 39 of Set 10 | manono
# Processing Record 40 of Set 10 | high level
# Processing Record 41 of Set 10 | vagur
# Processing Record 42 of Set 10 | vega de alatorre
# Processing Record 43 of Set 10 | boende
# Processing Record 44 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 45 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 46 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 10 | pareora
# Processing Record 48 of Set 10 | bosobolo
# Processing Record 49 of Set 10 | sola
# Processing Record 50 of Set 10 | nivala
# Processing Record 1 of Set 11 | sao joao da barra
# Processing Record 2 of Set 11 | lamu
# Processing Record 3 of Set 11 | iwaki
# Processing Record 4 of Set 11 | mao
# Processing Record 5 of Set 11 | souillac
# Processing Record 6 of Set 11 | santa fe
# Processing Record 7 of Set 11 | mnogovershinnyy
# Processing Record 8 of Set 11 | belyy yar
# Processing Record 9 of Set 11 | almaznyy
# Processing Record 10 of Set 11 | lakes entrance
# Processing Record 11 of Set 11 | acarau
# Processing Record 12 of Set 11 | zyryanka
# Processing Record 13 of Set 11 | wewak
# Processing Record 14 of Set 11 | qinhuangdao
# Processing Record 15 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 16 of Set 11 | semey
# Processing Record 17 of Set 11 | salinas
# Processing Record 18 of Set 11 | kargasok
# Processing Record 19 of Set 11 | cabo rojo
# Processing Record 20 of Set 11 | potosi
# Processing Record 21 of Set 11 | olga
# Processing Record 22 of Set 11 | jumla
# Processing Record 23 of Set 11 | seredka
# Processing Record 24 of Set 11 | kloulklubed
# Processing Record 25 of Set 11 | san cosme y damian
# Processing Record 26 of Set 11 | nabire
# Processing Record 27 of Set 11 | usinsk
# Processing Record 28 of Set 11 | komsomolskiy
# Processing Record 29 of Set 11 | praya
# Processing Record 30 of Set 11 | bida
# Processing Record 31 of Set 11 | chongqing
# Processing Record 32 of Set 11 | bantva
# Processing Record 33 of Set 11 | lawrenceburg
# Processing Record 34 of Set 11 | brae
# Processing Record 35 of Set 11 | flinders
# Processing Record 36 of Set 11 | comodoro rivadavia
# Processing Record 37 of Set 11 | aksarayskiy
# Processing Record 38 of Set 11 | saiki
# Processing Record 39 of Set 11 | hay river
# Processing Record 40 of Set 11 | bengkulu
# Processing Record 41 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 42 of Set 11 | collie
# Processing Record 43 of Set 11 | terra santa
# Processing Record 44 of Set 11 | oksfjord
# Processing Record 45 of Set 11 | broken hill
# Processing Record 46 of Set 11 | belle fourche
# Processing Record 47 of Set 11 | dubbo
# Processing Record 48 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 49 of Set 11 | naryan-mar
# Processing Record 50 of Set 11 | labuhan
# Processing Record 1 of Set 12 | manuk mangkaw
# Processing Record 2 of Set 12 | half moon bay
# Processing Record 3 of Set 12 | sinnamary
# Processing Record 4 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 5 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 6 of Set 12 | sidi ali
# Processing Record 7 of Set 12 | mitsamiouli
# Processing Record 8 of Set 12 | sile
# Processing Record 9 of Set 12 | jieshi
# Processing Record 10 of Set 12 | muros
# Processing Record 11 of Set 12 | asau
# Processing Record 12 of Set 12 | solnechnyy
# Processing Record 13 of Set 12 | chuzhou
# Processing Record 14 of Set 12 | oussouye
# Processing Record 15 of Set 12 | salta
# Processing Record 16 of Set 12 | novikovo
# Processing Record 17 of Set 12 | yanam
# Processing Record 18 of Set 12 | male
# Processing Record 19 of Set 12 | nemuro
# Processing Record 20 of Set 12 | veles
# Processing Record 21 of Set 12 | spearfish
# Processing Record 22 of Set 12 | senahu
# Processing Record 23 of Set 12 | egvekinot
# Processing Record 24 of Set 12 | moron
# Processing Record 25 of Set 12 | salalah
# Processing Record 26 of Set 12 | cauquenes
# Processing Record 27 of Set 12 | sulphur
# Processing Record 28 of Set 12 | kungurtug
# Processing Record 29 of Set 12 | liwale
# Processing Record 30 of Set 12 | maungaturoto
# Processing Record 31 of Set 12 | kiunga
# Processing Record 32 of Set 12 | misratah
# Processing Record 33 of Set 12 | barabinsk
# Processing Record 34 of Set 12 | rockland
# Processing Record 35 of Set 12 | colares
# Processing Record 36 of Set 12 | henties bay
# Processing Record 37 of Set 12 | nargana
# Processing Record 38 of Set 12 | berlevag
# Processing Record 39 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 12 | kollumerland
# City not found. Skipping...
# Processing Record 41 of Set 12 | urbano santos
# Processing Record 42 of Set 12 | ler
# Processing Record 43 of Set 12 | chilliwack
# Processing Record 44 of Set 12 | tambura
# Processing Record 45 of Set 12 | mugan
# Processing Record 46 of Set 12 | sydney
# Processing Record 47 of Set 12 | barcelona
# Processing Record 48 of Set 12 | montevideo
# Processing Record 49 of Set 12 | katherine
# Processing Record 50 of Set 12 | ramasukha
# City not found. Skipping...
# Processing Record 1 of Set 13 | mengcheng
# Processing Record 2 of Set 13 | north branch
# Processing Record 3 of Set 13 | indian head
# Processing Record 4 of Set 13 | hanzhong
# Processing Record 5 of Set 13 | santa luzia
# Processing Record 6 of Set 13 | mukhen
# Processing Record 7 of Set 13 | sosnovo
# Processing Record 8 of Set 13 | yarmouth
# Processing Record 9 of Set 13 | mwinilunga
# Processing Record 10 of Set 13 | alta floresta
# Processing Record 11 of Set 13 | derzhavinsk
# Processing Record 12 of Set 13 | taganak
# Processing Record 13 of Set 13 | meybod
# Processing Record 14 of Set 13 | seryshevo
# Processing Record 15 of Set 13 | la primavera
# Processing Record 16 of Set 13 | palmer
# Processing Record 17 of Set 13 | mananjary
# Processing Record 18 of Set 13 | rundu
# Processing Record 19 of Set 13 | tunduru
# City not found. Skipping...
# Processing Record 20 of Set 13 | castlerea
# Processing Record 21 of Set 13 | icatu
# Processing Record 22 of Set 13 | mizdah
# Processing Record 23 of Set 13 | pimenta bueno
# Processing Record 24 of Set 13 | shetpe
# Processing Record 25 of Set 13 | peterhead
# Processing Record 26 of Set 13 | phan thiet
# Processing Record 27 of Set 13 | yarada
# Processing Record 28 of Set 13 | wuwei
# Processing Record 29 of Set 13 | bang saphan
# Processing Record 30 of Set 13 | havelock
# Processing Record 31 of Set 13 | uruzgan
# Processing Record 32 of Set 13 | nueva loja
# Processing Record 33 of Set 13 | singaraja
# Processing Record 34 of Set 13 | moyobamba
# Processing Record 35 of Set 13 | boo
# Processing Record 36 of Set 13 | sambava
# Processing Record 37 of Set 13 | okara
# Processing Record 38 of Set 13 | atbasar
# Processing Record 39 of Set 13 | gazni
# City not found. Skipping...
# Processing Record 40 of Set 13 | maymyo
# Processing Record 41 of Set 13 | omboue
# Processing Record 42 of Set 13 | bucerias
# Processing Record 43 of Set 13 | sovetskiy
# Processing Record 44 of Set 13 | matamoros
# Processing Record 45 of Set 13 | port hedland
# Processing Record 46 of Set 13 | aracruz
# Processing Record 47 of Set 13 | destin
# Processing Record 48 of Set 13 | plettenberg bay
# Processing Record 49 of Set 13 | keighley
# Processing Record 50 of Set 13 | alpine
# Processing Record 1 of Set 14 | port shepstone
# Processing Record 2 of Set 14 | wawa
# Processing Record 3 of Set 14 | dolores
# Processing Record 4 of Set 14 | andenes
# Processing Record 5 of Set 14 | hohhot
# Processing Record 6 of Set 14 | mbandaka
# Processing Record 7 of Set 14 | platanos
# Processing Record 8 of Set 14 | ca mau
# Processing Record 9 of Set 14 | turbat
# Processing Record 10 of Set 14 | kaiyuan
# Processing Record 11 of Set 14 | altamont
# Processing Record 12 of Set 14 | opuwo
# Processing Record 13 of Set 14 | batemans bay
# Processing Record 14 of Set 14 | mahon
# Processing Record 15 of Set 14 | bud
# Processing Record 16 of Set 14 | olinda
# Processing Record 17 of Set 14 | batagay-alyta
# Processing Record 18 of Set 14 | sancti spiritus
# Processing Record 19 of Set 14 | kununurra
# Processing Record 20 of Set 14 | udachnyy
# Processing Record 21 of Set 14 | morant bay
# Processing Record 22 of Set 14 | toba
# Processing Record 23 of Set 14 | pankrushikha
# Processing Record 24 of Set 14 | loreto
# Processing Record 25 of Set 14 | aklavik
# Processing Record 26 of Set 14 | trairi
# Processing Record 27 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 14 | viseu
# Processing Record 29 of Set 14 | los chiles
# Processing Record 30 of Set 14 | dangriga
# Processing Record 31 of Set 14 | nouakchott
# Processing Record 32 of Set 14 | araouane
# Processing Record 33 of Set 14 | tambilil
# Processing Record 34 of Set 14 | tessalit
# Processing Record 35 of Set 14 | genhe
# Processing Record 36 of Set 14 | polunochnoye
# Processing Record 37 of Set 14 | bereda
# Processing Record 38 of Set 14 | hunza
# City not found. Skipping...
# Processing Record 39 of Set 14 | manaure
# Processing Record 40 of Set 14 | tomar
# Processing Record 41 of Set 14 | parintins
# Processing Record 42 of Set 14 | aracaju
# Processing Record 43 of Set 14 | cermik
# Processing Record 44 of Set 14 | verkhnyaya inta
# Processing Record 45 of Set 14 | kasiri
# Processing Record 46 of Set 14 | timbiqui
# Processing Record 47 of Set 14 | leningradskiy
# Processing Record 48 of Set 14 | birjand
# Processing Record 49 of Set 14 | deputatskiy
# Processing Record 50 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 1 of Set 15 | kamalpur
# Processing Record 2 of Set 15 | matiri
# Processing Record 3 of Set 15 | saint-joseph
# Processing Record 4 of Set 15 | temaraia
# City not found. Skipping...
# Processing Record 5 of Set 15 | kesinga
# Processing Record 6 of Set 15 | jibuti
# Processing Record 7 of Set 15 | sao jose da coroa grande
# Processing Record 8 of Set 15 | angoche
# Processing Record 9 of Set 15 | san pedro
# Processing Record 10 of Set 15 | tomra
# Processing Record 11 of Set 15 | ahipara
# Processing Record 12 of Set 15 | faya
# Processing Record 13 of Set 15 | tawau
# Processing Record 14 of Set 15 | mana
# Processing Record 15 of Set 15 | hovd
# Processing Record 16 of Set 15 | salaga
# Processing Record 17 of Set 15 | kuldur
# Processing Record 18 of Set 15 | padang
# Processing Record 19 of Set 15 | santiago del estero
# Processing Record 20 of Set 15 | marsa matruh
# Processing Record 21 of Set 15 | laramie
# Processing Record 22 of Set 15 | manbij
# Processing Record 23 of Set 15 | jaguaruna
# Processing Record 24 of Set 15 | tuban
# Processing Record 25 of Set 15 | lisakovsk
# Processing Record 26 of Set 15 | cameron park
# Processing Record 27 of Set 15 | takoradi
# Processing Record 28 of Set 15 | makaryev
# Processing Record 29 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 30 of Set 15 | baiyin
# Processing Record 31 of Set 15 | doha
# Processing Record 32 of Set 15 | luena
# Processing Record 33 of Set 15 | west plains
# Processing Record 34 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 35 of Set 15 | douentza
# Processing Record 36 of Set 15 | gombong
# Processing Record 37 of Set 15 | ust-ishim
# Processing Record 38 of Set 15 | ondorhaan
# City not found. Skipping...
# Processing Record 39 of Set 15 | cairns
# Processing Record 40 of Set 15 | gigmoto
# Processing Record 41 of Set 15 | san jose
# Processing Record 42 of Set 15 | caronport
# Processing Record 43 of Set 15 | nortelandia
# Processing Record 44 of Set 15 | codajas
# Processing Record 45 of Set 15 | pouebo
# Processing Record 46 of Set 15 | yaqui
# Processing Record 47 of Set 15 | yerbogachen
# Processing Record 48 of Set 15 | cody
# Processing Record 49 of Set 15 | povenets
# Processing Record 50 of Set 15 | tarnogskiy gorodok
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Hobart -42.88  147.33     45.00        81          75       11.41
# 1          Kapaa  22.08 -159.32     87.80        58          40       11.41
# 2        Honiara  -9.43  159.95     87.80        66          20        5.82
# 3        Mataura -46.19  168.86     69.01        51          32       18.01
# 4  Mount Gambier -37.83  140.77     50.00        87          90        6.93
# 5      Jamestown  42.10  -79.24     53.60        66          90        3.74
# 6     Kaitangata -46.28  169.85     70.00        43          69        7.00
# 7     San Andres  12.58  -81.70     84.20        79          75        4.70
# 8        Rikitea -23.12 -134.97     73.42        79          17       15.46
# 9      Upernavik  72.79  -56.15     24.58        87          85        4.09
#
#   Weather Description Country
# 0       broken clouds      AU
# 1    scattered clouds      US
# 2          few clouds      SB
# 3    scattered clouds      NZ
# 4     overcast clouds      AU
# 5       moderate rain      US
# 6       broken clouds      NZ
# 7       broken clouds      CO
# 8          few clouds      PF
# 9     overcast clouds      GL

# %%
new_column_order=['City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Weather Description']
city_data_df=city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0         Hobart      AU -42.88  147.33     45.00        81          75
# 1          Kapaa      US  22.08 -159.32     87.80        58          40
# 2        Honiara      SB  -9.43  159.95     87.80        66          20
# 3        Mataura      NZ -46.19  168.86     69.01        51          32
# 4  Mount Gambier      AU -37.83  140.77     50.00        87          90
# 5      Jamestown      US  42.10  -79.24     53.60        66          90
# 6     Kaitangata      NZ -46.28  169.85     70.00        43          69
# 7     San Andres      CO  12.58  -81.70     84.20        79          75
# 8        Rikitea      PF -23.12 -134.97     73.42        79          17
# 9      Upernavik      GL  72.79  -56.15     24.58        87          85
#
#    Wind Speed Weather Description
# 0       11.41       broken clouds
# 1       11.41    scattered clouds
# 2        5.82          few clouds
# 3       18.01    scattered clouds
# 4        6.93     overcast clouds
# 5        3.74       moderate rain
# 6        7.00       broken clouds
# 7        4.70       broken clouds
# 8       15.46          few clouds
# 9        4.09     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
